# %%
from tribulnation.sdk import EarnSDK, accounts
from dotenv import load_dotenv

load_dotenv()

earn = EarnSDK({
  'binance': accounts.Binance(),
  'mexc': accounts.Mexc()
})

# %%
for account, sdk in earn.all.items():
  print(f'[{account}]')
  instruments = await sdk.instruments()
  for instr in instruments[:10]:
    print(f'> {instr.asset} {instr.apr:.2%}')
  if len(instruments) > 10:
    print(f'> ... and {len(instruments) - 10} more instruments')
  print()
# Out:
# [mexc]
# > USDGO 10.00%
# > USDGO 4.00%
# > USDGO 3.00%
# > USD1 9.00%
# > USD1 2.00%
# > USD1 600.00%
# > USDT 15.00%
# > USDT 6.00%
# > USDT 1.00%
# > USDT 600.00%
# > ... and 43 more instruments
#
# [binance]
# > EURI 8.39%
# > AVA 1.24%
# > PEPE 0.14%
# > GMT 3.67%
# > LAYER 13.57%
# > SOLV 0.96%
# > ACE 5.81%
# > REZ 1.74%
# > PIXEL 13.51%
# > DYM 10.47%
# > ... and 630 more instruments
