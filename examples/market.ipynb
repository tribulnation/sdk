# %%
import os
from tribulnation.sdk import MarketSDK, accounts
from dotenv import load_dotenv

load_dotenv()

market = MarketSDK({
  'dydx-account1': accounts.Dydx(),
})

# %%
await market.available_notional('dydx-account1:perp:BTC-USD:256')
# Out:
# Decimal('0E+1')
